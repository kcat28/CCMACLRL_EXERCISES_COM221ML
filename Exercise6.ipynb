# %% [markdown]
# <a href="https://colab.research.google.com/github/kcat28/CCMACLRL_EXERCISES_COM221ML/blob/main/Exercise6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Dataset File

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXERCISES/blob/f5fdfba1aabbbafcf2fe49ca6e1c8f92f69d1458/datasets/titanic/train.csv?raw=true'
df = pd.read_csv(dataset_url)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 28            29         1       3
# 170          171         0       1
# 537          538         1       1
# 417          418         1       2
# 560          561         0       3
# 163          164         0       3
# 468          469         0       3
# 514          515         0       3
# 470          471         0       3
# 200          201         0       3
# 529          530         0       2
# 214          215         0       3
# 45            46         0       3
# 218          219         1       1
# 548          549         0       3
# 74            75         1       3
# 76            77         0       3
# 866          867         1       2
# 726          727         1       2
# 743          744         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 28                 O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0      0
# 170                    Van der hoef, Mr. Wyckoff    male  61.0      0      0
# 537                          LeRoy, Miss. Bertha  female  30.0      0      0
# 417                Silven, Miss. Lyyli Karoliina  female  18.0      0      2
# 560                     Morrow, Mr. Thomas Rowan    male   NaN      0      0
# 163                              Calic, Mr. Jovo    male  17.0      0      0
# 468                           Scanlan, Mr. James    male   NaN      0      0
# 514                            Coleff, Mr. Satio    male  24.0      0      0
# 470                            Keefe, Mr. Arthur    male   NaN      0      0
# 200               Vande Walle, Mr. Nestor Cyriel    male  28.0      0      0
# 529                  Hocking, Mr. Richard George    male  23.0      2      1
# 214                          Kiernan, Mr. Philip    male   NaN      1      0
# 45                      Rogers, Mr. William John    male   NaN      0      0
# 218                        Bazzani, Miss. Albina  female  32.0      0      0
# 548                    Goldsmith, Mr. Frank John    male  33.0      1      1
# 74                                 Bing, Mr. Lee    male  32.0      0      0
# 76                             Staneff, Mr. Ivan    male   NaN      0      0
# 866                 Duran y More, Miss. Asuncion  female  27.0      1      0
# 726  Renouf, Mrs. Peter Henry (Lillian Jefferys)  female  30.0      3      0
# 743                            McNamee, Mr. Neal    male  24.0      1      0
#
#               Ticket      Fare Cabin Embarked
# 28            330959    7.8792   NaN        Q
# 170           111240   33.5000   B19        S
# 537         PC 17761  106.4250   NaN        C
# 417           250652   13.0000   NaN        S
# 560           372622    7.7500   NaN        Q
# 163           315093    8.6625   NaN        S
# 468            36209    7.7250   NaN        Q
# 514           349209    7.4958   NaN        S
# 470           323592    7.2500   NaN        S
# 200           345770    9.5000   NaN        S
# 529            29104   11.5000   NaN        S
# 214           367229    7.7500   NaN        Q
# 45   S.C./A.4. 23567    8.0500   NaN        S
# 218            11813   76.2917   D15        C
# 548           363291   20.5250   NaN        S
# 74              1601   56.4958   NaN        S
# 76            349208    7.8958   NaN        S
# 866    SC/PARIS 2149   13.8583   NaN        C
# 726            31027   21.0000   NaN        S
# 743           376566   16.1000   NaN        S

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df = df[['Survived', 'Age', 'Sex', 'Pclass', 'Embarked', 'Parch',]]
df = pd.get_dummies(df, columns=['Sex', 'Pclass',])
df.dropna(inplace=True)

# %%
df.sample(10)
# Out:
#      Survived   Age Embarked  Parch  Sex_female  Sex_male  Pclass_1  Pclass_2  \
# 198         1  28.0        Q      0        True     False     False     False
# 241         1  28.0        Q      0        True     False     False     False
# 274         1  28.0        Q      0        True     False     False     False
# 277         0  28.0        S      0       False      True     False      True
# 399         1  28.0        S      0        True     False     False      True
# 262         0  52.0        S      1       False      True      True     False
# 381         1   1.0        C      2        True     False     False     False
# 100         0  28.0        S      0        True     False     False     False
# 302         0  19.0        S      0       False      True     False     False
# 55          1  28.0        S      0       False      True      True     False
#
#      Pclass_3
# 198      True
# 241      True
# 274      True
# 277     False
# 399     False
# 262     False
# 381      True
# 100      True
# 302      True
# 55      False

# %%
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    889 non-null    int64
#  1   Age         889 non-null    float64
#  2   Embarked    889 non-null    int64
#  3   Parch       889 non-null    int64
#  4   Sex_female  889 non-null    bool
#  5   Sex_male    889 non-null    bool
#  6   Pclass_1    889 non-null    bool
#  7   Pclass_2    889 non-null    bool
#  8   Pclass_3    889 non-null    bool
# dtypes: bool(5), float64(1), int64(3)
# memory usage: 39.1 KB

# %%
x = df.drop('Survived', axis=1)
y = df['Survived']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)

# %%
model = LogisticRegression(random_state=0)
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
model.score(x_test, y_test)
# Out:
# 0.8370786516853933

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(model, x, y, cv=5).mean()
# Out:
# 0.7919253475528472

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    889 non-null    int64
#  1   Age         889 non-null    float64
#  2   Embarked    889 non-null    int64
#  3   Parch       889 non-null    int64
#  4   Sex_female  889 non-null    bool
#  5   Sex_male    889 non-null    bool
#  6   Pclass_1    889 non-null    bool
#  7   Pclass_2    889 non-null    bool
#  8   Pclass_3    889 non-null    bool
# dtypes: bool(5), float64(1), int64(3)
# memory usage: 39.1 KB

# %% [markdown]
# ## Test File

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXERCISES/blob/f5fdfba1aabbbafcf2fe49ca6e1c8f92f69d1458/datasets/titanic/test.csv?raw=true'
dt=pd.read_csv(test_url)

# %%
dt = dt[['Age', 'Sex', 'Pclass', 'Embarked', 'Parch',]]
dt['Embarked'] = dt['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})
dt['Age'].fillna(dt['Age'].median(), inplace=True)
dt = pd.get_dummies(dt, columns=['Sex', 'Pclass',])
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         418 non-null    float64
#  1   Embarked    418 non-null    int64
#  2   Parch       418 non-null    int64
#  3   Sex_female  418 non-null    bool
#  4   Sex_male    418 non-null    bool
#  5   Pclass_1    418 non-null    bool
#  6   Pclass_2    418 non-null    bool
#  7   Pclass_3    418 non-null    bool
# dtypes: bool(5), float64(1), int64(2)
# memory usage: 12.0 KB

# %%
dt.sample(10)
# Out:
#       Age  Embarked  Parch  Sex_female  Sex_male  Pclass_1  Pclass_2  Pclass_3
# 219  27.0         0      0       False      True     False     False      True
# 15   24.0         1      0        True     False     False      True     False
# 321  25.0         1      0       False      True     False     False      True
# 315  17.0         2      0        True     False     False     False      True
# 414  39.0         1      0        True     False      True     False     False
# 38   25.0         0      0       False      True     False     False      True
# 356  59.0         0      0        True     False      True     False     False
# 409   3.0         0      1        True     False     False     False      True
# 383  19.0         0      0        True     False     False     False      True
# 335  30.0         0      0       False      True      True     False     False

# %% [markdown]
# ## Sample Submission File

# %%
sample_submission_url ='https://github.com/robitussin/CCMACLRL_EXERCISES/blob/f5fdfba1aabbbafcf2fe49ca6e1c8f92f69d1458/datasets/titanic/gender_submission.csv?raw=true'

sf=pd.read_csv(sample_submission_url)

# %%
sf.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
id = sf.pop('PassengerId')
y_pred = model.predict(dt)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'PassengerId': id,
    'Survived': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('results.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
